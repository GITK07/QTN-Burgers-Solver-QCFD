# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../results/validation.csv")

plt.plot(df["Time"], df["L2 Error"], marker='o')
plt.title("L2 Error vs Time")
plt.xlabel("Time Step")
plt.ylabel("L2 Error")
plt.grid()
plt.show()
